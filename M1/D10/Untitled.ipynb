# %%
import pandas as pd
import numpy as np

import requests
from requests import get
from bs4 import BeautifulSoup

from time import sleep
from random import randint

# %%
# Creating the lists we want to write into
titles = []
years = []
time = []
imdb_ratings = []
metascores = []
votes = []
us_gross = []

# %%
# Getting English translated titles from the movies
headers = {'Accept-Language': 'en-US, en;q=0.5'}

# %%
pages = np.arange(1, 301, 100)
pages
# Out:
# array([  1, 101, 201])

# %%
# Storing each of the urls of 50 movies 
for page in pages:
    # Getting the contents from the each url
#     page = requests.get('https://www.imdb.com/list/ls009318269/?st_dt=&mode=detail&page=' + str(page) + '&ref_=adv_nxt', headers=headers)
    page = requests.get('https://www.imdb.com/search/title/?groups=top_1000&start=' + str(page) + '&ref_=adv_nxt', headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    # Aiming the part of the html we want to get the information from
    movie_div = soup.find_all('div', class_='lister-item mode-advanced')
    
    # Controling the loop’s rate by pausing the execution of the loop for a specified amount of time
    # Waiting time between requests for a number between 2-10 seconds
    sleep(randint(2,10))
    
    for container in movie_div:
        # Scraping the movie's name
        name = container.h3.a.text
        titles.append(name)
        
        # Scraping the movie's year
        year = container.h3.find('span', class_='lister-item-year').text
        years.append(year)
        
        # Scraping the movie's length
        runtime = container.find('span', class_='runtime').text if container.p.find('span', class_='runtime') else '-'
        time.append(runtime)
        
        # Scraping the rating
        imdb = float(container.strong.text)
        imdb_ratings.append(imdb)
        
        # Scraping the metascore
        m_score = container.find('span', class_='metascore').text if container.find('span', class_='metascore') else '-'
        metascores.append(m_score)
        
        # Scraping votes and gross earnings
        nv = container.find_all('span', attrs={'name':'nv'})
        vote = nv[0].text
        votes.append(vote)
        grosses = nv[1].text if len(nv) > 1 else '-'
        us_gross.append(grosses)

# %%
movies = pd.DataFrame({'movie':titles,
                       'year':years,
                       'time_minute':time,
                       'imdb_rating':imdb_ratings,
                       'metascore':metascores,
                       'vote':votes,
                       'gross_earning':us_gross})

movies.head()
# Out:
# Empty DataFrame
# Columns: [movie, year, time_minute, imdb_rating, metascore, vote, gross_earning]
# Index: []

# %%
movies.dtypes
# Out:
# movie            float64
# year             float64
# time_minute      float64
# imdb_rating      float64
# metascore        float64
# vote             float64
# gross_earning    float64
# dtype: object

# %%
# Cleaning 'year' column
movies['year'] = movies['year'].str.extract('(\d+)').astype(int)
movies.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-f8cdc0a10a1e> in <module>
#       1 # Cleaning 'year' column
# ----> 2 movies['year'] = movies['year'].str.extract('(\d+)').astype(int)
#       3 movies.head(3)
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
#     182         # https://www.pydanny.com/cached-property.html
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     152         from pandas.core.arrays.string_ import StringDtype
#     153
# --> 154         self._inferred_dtype = self._validate(data)
#     155         self._is_categorical = is_categorical_dtype(data.dtype)
#     156         self._is_string = isinstance(data.dtype, StringDtype)
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/pandas/core/strings/accessor.py in _validate(data)
#     215
#     216         if inferred_dtype not in allowed_types:
# --> 217             raise AttributeError("Can only use .str accessor with string values!")
#     218         return inferred_dtype
#     219
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Cleaning 'time_minute' column
movies['time_minute'] = movies['time_minute'].str.extract('(\d+)').astype(int)
movies.head(3)
# Out:
#                           movie  year  time_minute  imdb_rating   metascore  \
# 0  Zack Snyder's Justice League  2021          242          8.2  54
# 1          The Ten Commandments  1956          220          7.9           -
# 2                    The Father  2020           97          8.3  88
#
#       vote gross_earning
# 0  258,456             -
# 1   65,015       $93.74M
# 2   27,678             -

# %%
# Cleaning 'metascore' column
movies['metascore'] = movies['metascore'].str.extract('(\d+)')
# convert it to float and if there are dashes turn it into NaN
movies['metascore'] = pd.to_numeric(movies['metascore'], errors='coerce')

# %%
# Cleaning 'vote' column
movies['vote'] = movies['vote'].str.replace(',', '').astype(int)
movies.head(3)
# Out:
#                           movie  year  time_minute  imdb_rating  metascore  \
# 0  Zack Snyder's Justice League  2021          242          8.2       54.0
# 1          The Ten Commandments  1956          220          7.9        NaN
# 2                    The Father  2020           97          8.3       88.0
#
#      vote gross_earning
# 0  258456             -
# 1   65015       $93.74M
# 2   27678             -

# %%
# Cleaning 'gross_earning' column
# left strip $ and right strip M 
movies['gross_earning'] = movies['gross_earning'].map(lambda x: x.lstrip('$').rstrip('M'))
# convert it to float and if there are dashes turn it into NaN
movies['gross_earning'] = pd.to_numeric(movies['gross_earning'], errors='coerce')
movies.head(3)
# Out:
#                           movie  year  time_minute  imdb_rating  metascore  \
# 0  Zack Snyder's Justice League  2021          242          8.2       54.0
# 1          The Ten Commandments  1956          220          7.9        NaN
# 2                    The Father  2020           97          8.3       88.0
#
#      vote  gross_earning
# 0  258456            NaN
# 1   65015          93.74
# 2   27678            NaN

# %%
movies.dtypes
# Out:
# movie             object
# year               int64
# time_minute        int64
# imdb_rating      float64
# metascore        float64
# vote               int64
# gross_earning    float64
# dtype: object

# %%
movies
# Out:
#                                       movie  year  time_minute  imdb_rating  \
# 0              Zack Snyder's Justice League  2021          242          8.2
# 1                      The Ten Commandments  1956          220          7.9
# 2                                The Father  2020           97          8.3
# 3                                  Sleepers  1996          147          7.6
# 4    Harry Potter and the Half-Blood Prince  2009          153          7.6
# ..                                      ...   ...          ...          ...
# 345                              The Others  2001          104          7.6
# 346                              Just Mercy  2019          137          7.6
# 347                                3 Idiots  2009          170          8.4
# 348                        Some Like It Hot  1959          121          8.2
# 349                       Dog Day Afternoon  1975          125          8.0
#
#      metascore    vote  gross_earning
# 0         54.0  258456            NaN
# 1          NaN   65015          93.74
# 2         88.0   27678            NaN
# 3         49.0  193257          49.10
# 4         78.0  482370         301.96
# ..         ...     ...            ...
# 345       74.0  341120          96.52
# 346       68.0   49938            NaN
# 347       67.0  350228           6.53
# 348       98.0  246804          25.00
# 349       86.0  238197          50.00
#
# [350 rows x 7 columns]

# %%
movies.to_csv('movies_test.csv')

# %%
df = pd.read_csv('movies_test.csv')

# %%
df
# Out:
#      Unnamed: 0                                   movie  year  time_minute  \
# 0             0            Zack Snyder's Justice League  2021          242
# 1             1                    The Ten Commandments  1956          220
# 2             2                              The Father  2020           97
# 3             3                                Sleepers  1996          147
# 4             4  Harry Potter and the Half-Blood Prince  2009          153
# ..          ...                                     ...   ...          ...
# 345         345                              The Others  2001          104
# 346         346                              Just Mercy  2019          137
# 347         347                                3 Idiots  2009          170
# 348         348                        Some Like It Hot  1959          121
# 349         349                       Dog Day Afternoon  1975          125
#
#      imdb_rating  metascore    vote  gross_earning
# 0            8.2       54.0  258456            NaN
# 1            7.9        NaN   65015          93.74
# 2            8.3       88.0   27678            NaN
# 3            7.6       49.0  193257          49.10
# 4            7.6       78.0  482370         301.96
# ..           ...        ...     ...            ...
# 345          7.6       74.0  341120          96.52
# 346          7.6       68.0   49938            NaN
# 347          8.4       67.0  350228           6.53
# 348          8.2       98.0  246804          25.00
# 349          8.0       86.0  238197          50.00
#
# [350 rows x 8 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0                                   movie  year  time_minute  \
# 0           0            Zack Snyder's Justice League  2021          242
# 1           1                    The Ten Commandments  1956          220
# 2           2                              The Father  2020           97
# 3           3                                Sleepers  1996          147
# 4           4  Harry Potter and the Half-Blood Prince  2009          153
# 5           5                          Sound of Metal  2019          120
# 6           6              The Trial of the Chicago 7  2020          129
# 7           7                       Avengers: Endgame  2019          181
# 8           8                           The Godfather  1972          175
# 9           9                     Saving Private Ryan  1998          169
#
#    imdb_rating  metascore     vote  gross_earning
# 0          8.2       54.0   258456            NaN
# 1          7.9        NaN    65015          93.74
# 2          8.3       88.0    27678            NaN
# 3          7.6       49.0   193257          49.10
# 4          7.6       78.0   482370         301.96
# 5          7.8       82.0    59593            NaN
# 6          7.8       76.0   128456            NaN
# 7          8.4       78.0   854754         858.37
# 8          9.2      100.0  1645702         134.97
# 9          8.6       91.0  1252798         216.54

# %%
df.shape[0]
# Out:
# 350

# %%
df.sort_values(by='imdb_rating', ascending=False)
# Out:
#      Unnamed: 0                                   movie  year  time_minute  \
# 165         165                The Shawshank Redemption  1994          142
# 15           15                The Shawshank Redemption  1994          142
# 8             8                           The Godfather  1972          175
# 158         158                           The Godfather  1972          175
# 13           13                         The Dark Knight  2008          152
# ..          ...                                     ...   ...          ...
# 315         315                               Apollo 13  1995          140
# 154         154  Harry Potter and the Half-Blood Prince  2009          153
# 292         292                                Kick-Ass  2010          117
# 11           11   Harry Potter and the Sorcerer's Stone  2001          152
# 64           64                                   Moana  2016          107
#
#      imdb_rating  metascore     vote  gross_earning
# 165          9.3       80.0  2376024          28.34
# 15           9.3       80.0  2376024          28.34
# 8            9.2      100.0  1645702         134.97
# 158          9.2      100.0  1645702         134.97
# 13           9.0       84.0  2339823         534.86
# ..           ...        ...      ...            ...
# 315          7.6       77.0   272910         173.84
# 154          7.6       78.0   482370         301.96
# 292          7.6       66.0   528696          48.07
# 11           7.6       64.0   669351         317.58
# 64           7.6       81.0   279256         248.76
#
# [350 rows x 8 columns]

# %%
df.sort_values(by='metascore', ascending=False)
# Out:
#      Unnamed: 0                           movie  year  time_minute  \
# 158         158                   The Godfather  1972          175
# 8             8                   The Godfather  1972          175
# 348         348                Some Like It Hot  1959          121
# 318         318                   Seven Samurai  1954          207
# 132         132                 Pan's Labyrinth  2006          118
# ..          ...                             ...   ...          ...
# 333         333  Fear and Loathing in Las Vegas  1998          118
# 1             1            The Ten Commandments  1956          220
# 106         106             The Invisible Guest  2016          106
# 151         151            The Ten Commandments  1956          220
# 256         256             The Invisible Guest  2016          106
#
#      imdb_rating  metascore     vote  gross_earning
# 158          9.2      100.0  1645702         134.97
# 8            9.2      100.0  1645702         134.97
# 348          8.2       98.0   246804          25.00
# 318          8.6       98.0   319687           0.27
# 132          8.2       98.0   624766          37.63
# ..           ...        ...      ...            ...
# 333          7.6       41.0   262033          10.68
# 1            7.9        NaN    65015          93.74
# 106          8.1        NaN   149449            NaN
# 151          7.9        NaN    65015          93.74
# 256          8.1        NaN   149449            NaN
#
# [350 rows x 8 columns]

# %%
df.sort_values(by='gross_earning', ascending=False)
# Out:
#      Unnamed: 0                   movie  year  time_minute  imdb_rating  \
# 7             7       Avengers: Endgame  2019          181          8.4
# 157         157       Avengers: Endgame  2019          181          8.4
# 170         170  Avengers: Infinity War  2018          149          8.4
# 20           20  Avengers: Infinity War  2018          149          8.4
# 28           28                 Titanic  1997          194          7.8
# ..          ...                     ...   ...          ...          ...
# 162         162           Another Round  2020          117          7.8
# 171         171           The Gentlemen  2019          113          7.8
# 256         256     The Invisible Guest  2016          106          8.1
# 311         311                   Giant  1956          201          7.6
# 346         346              Just Mercy  2019          137          7.6
#
#      metascore     vote  gross_earning
# 7         78.0   854754         858.37
# 157       78.0   854754         858.37
# 170       68.0   864188         678.82
# 20        68.0   864188         678.82
# 28        75.0  1059437         659.33
# ..         ...      ...            ...
# 162       80.0    58594            NaN
# 171       51.0   256382            NaN
# 256        NaN   149449            NaN
# 311       84.0    34566            NaN
# 346       68.0    49938            NaN
#
# [350 rows x 8 columns]
