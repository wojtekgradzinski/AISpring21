# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv(url)

plt.xlim(1,12)
plt.plot(data['month_number'],data['total_profit'])
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.title('Company Profit Per Month')
# Out:
# Text(0.5, 1.0, 'Company Profit Per Month')

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

plt.figure(figsize=[10,8])
plt.xlim(0,12.5)
plt.plot(data['month_number'],data['total_profit'],color='r', marker='o',linestyle='--',linewidth=3,markersize=6, markerfacecolor='black')
plt.xlabel('Month Number')
plt.ylabel('Profit')
plt.title('Company Sales Data Of Last Year')
# Out:
# Text(0.5, 1.0, 'Company Sales Data Of Last Year')

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head(5)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))

products = [['facecream','b','facecream Sales Data'],
    ['facewash','c','facewash Sales Data'],
    ['toothpaste','g','toothpaste Sales Data'],
    ['bathingsoap','r','bathingsoap Sales Data'],
    ['shampoo','m','shampoo Sales Data'],
    ['moisturizer','k','moisturizer Sales Data']]

for product in products:
    plt.plot(data['month_number'],data[product[0]],color=product[1],label=product[2],marker='o',linewidth=3)
    
plt.xlabel('month numbers')
plt.ylabel('sales units in numbers')
plt.title('Sales Data')
plt.legend()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

fig = plt.subplots(figsize=(10,8))

plt.scatter(data['month_number'],data['toothpaste'],s=200)

plt.grid(linestyle='--',linewidth=3)

plt.xlabel('Month Number', fontsize=18)
plt.ylabel('Number of units sold', fontsize=18)
plt.title('Toothpaste Sales Data',fontsize=32)
# Out:
# Text(0.5, 1.0, 'Toothpaste Sales Data')

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig = plt.subplots(figsize=(10,8))
plt.bar(data['month_number']-0.2,data['facecream'],align='center',width=0.25)
plt.bar(data['month_number']+0.2,data['facewash'],align='center',width=0.25)


plt.grid(linestyle='--',linewidth=3)
plt.xlabel('Month Number', fontsize=20)
plt.ylabel('Number of units sold', fontsize=20)
plt.title('Facewash and Facecream Sales Data',fontsize=30)

colors = {'Facecream':'blue', 'Facewash':'orange'}  
labels = list(colors.keys())

handles = [plt.Rectangle((1,1),0,0, color=colors[label]) for label in labels]
plt.legend(handles, labels)

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.subplots(figsize=(10,8))
plt.bar(data['month_number'],data['total_units'],align='center',width=0.7)

plt.grid(linestyle='--',linewidth=2)
plt.xlabel('Month Number', fontsize=20)
plt.ylabel('Sales units in number', fontsize=20)
plt.title('Bathing Soap Sales Data',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Bathing Soap Sales Data')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.subplots(figsize=(10,8))
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [data['facecream'].sum(), data['facewash'].sum(), data['toothpaste'].sum(), 
         data['bathingsoap'].sum(), data['shampoo'].sum(), data['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels ,autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.subplots(figsize=(10,8))
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [data['facecream'].sum(), data['facewash'].sum(), data['toothpaste'].sum(), 
         data['bathingsoap'].sum(), data['shampoo'].sum(), data['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels ,autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
monthList  = data ['month_number'].tolist()
bathingsoap   = data ['bathingsoap'].tolist()
faceWashSalesData   = data ['facewash'].tolist()

f, axarr = plt.subplots(2, figsize=(10,8),sharex=True)
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)
axarr[0].set_title('Sales data of  a Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='r', marker='o', linewidth=3)
axarr[1].set_title('Sales data of  a facewash')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()

# %%
# Write your code here
plt.subplots(figsize=(15,8))
faceCremSalesData   = data ['facecream'].tolist()
faceWashSalesData   = data ['facewash'].tolist()
toothPasteSalesData = data ['toothpaste'].tolist()
bathingsoapSalesData   = data ['bathingsoap'].tolist()
shampooSalesData   = data ['shampoo'].tolist()
moisturizerSalesData = data ['moisturizer'].tolist()

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number', fontsize=18)
plt.ylabel('Sales unints in Number', fontsize=18)
plt.title('All product sales data using stack plot', fontsize=24)
plt.legend(loc='upper left')
plt.show()
