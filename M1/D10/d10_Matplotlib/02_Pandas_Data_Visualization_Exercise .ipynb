# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = {"a": np.random.random(500),
        "b": np.random.random(500),
        "c": np.random.random(500),
        "d": np.random.random(500)}
df3 = pd.DataFrame(data)
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.683405  0.003565  0.161175  0.710045
# 1  0.290194  0.524582  0.349108  0.542561
# 2  0.374061  0.343904  0.055015  0.579549
# 3  0.866871  0.653992  0.198844  0.603504
# 4  0.962547  0.704317  0.930657  0.105609

# %% [markdown]
# **Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
fig, ax = plt.subplots(figsize=(12,3))
plt.scatter(x = df3['a'],y = df3['b'],
    color='r',
    edgecolors='k',
    s=50)
plt.xlim(-0.2,1.2)
plt.ylim(-0.2,1.2)
plt.tick_params(axis='both',direction='in') #ticks
plt.xlabel('a', fontsize=12)
plt.ylabel('b', fontsize=12)
# Out:
# Text(0, 0.5, 'b')

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a histogram of the 'a' column.**

# %%
plt.hist(x = df3['a'], color='b', edgecolor='k')
plt.xlim(0,1)
plt.ylim(0,70)
plt.ylabel('Frequency', fontsize=10)
plt.tick_params(axis='both',direction='in',top=True,right=True)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
plt.hist(x = df3['a'], 
        color='red', 
        edgecolor='w', 
        alpha=0.4, 
        bins=25)
plt.xlim(0,1)
plt.tick_params(axis='both',direction='out',top=True,right=True)
plt.ylabel('Frequency', fontsize=10)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a boxplot comparing the a and b columns.**

# %%
df = [df3['a'],df3['b']]
fig, ax = plt.subplots(figsize=(10,8), linestyle='--', color='r')
plt.boxplot(df)
ax.set_xticklabels(['a', 'b'])
plt.ylim(0.0,1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-80592f5d5609> in <module>
#       1 df = [df3['a'],df3['b']]
# ----> 2 fig, ax = plt.subplots(figsize=(10,8), linestyle='--', color='r')
#       3 plt.boxplot(df)
#       4 ax.set_xticklabels(['a', 'b'])
#       5 plt.ylim(0.0,1.0)
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1285
#    1286     """
# -> 1287     fig = figure(**fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     685             dpi = 72
#     686
# --> 687         figManager = new_figure_manager(num, figsize=figsize,
#     688                                         dpi=dpi,
#     689                                         facecolor=facecolor,
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/matplotlib/pyplot.py in new_figure_manager(*args, **kwargs)
#     313     """Create a new figure manager instance."""
#     314     _warn_if_gui_out_of_main_thread()
# --> 315     return _backend_mod.new_figure_manager(*args, **kwargs)
#     316
#     317
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3491         from matplotlib.figure import Figure
#    3492         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3493         fig = fig_cls(*args, **kwargs)
#    3494         return cls.new_figure_manager_given_figure(num, fig)
#    3495
#
# TypeError: __init__() got an unexpected keyword argument 'linestyle'

# %%
#DO NOT TOUCH ME

# %%
df3['d'].plot.kde(alpha=0.5)
plt.ylabel('Density', fontsize=10)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.density(alpha=0.5,lw=5,ls='--')
plt.ylabel('Density', fontsize=10)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
# plt.subplots(figsize=(10,5))
# a   = data ['a'].tolist()
# b   = data ['b'].tolist()
# c = data ['c'].tolist()
# d   = data ['d'].tolist()


# plt.plot([],[],color='lightcoral', alpha=0.5, label='a')
# plt.plot([],[],color='skyblue', alpha=0.5, label='b')
# plt.plot([],[],color='plum', alpha=0.5, label='c')
# plt.plot([],[],color='darkgray', alpha=0.5, label='d')

# plt.ylim(0,3.0)

# plt.stackplot(a, b, c, d, 
#               colors=['lightcoral','skyblue','plum','darkgray'])

# plt.legend(loc='upper right')
# plt.show()

df3.ix[0:30].plot.area(alpha=0.5)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.75))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-7e2c2b4c27e6> in <module>
#      19 # plt.show()
#      20
# ---> 21 df3.ix[0:30].plot.area(alpha=0.5)
#      22 plt.legend(loc='center left', bbox_to_anchor=(1, 0.75))
#
# /opt/anaconda3/envs/fistaenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
#DO NOT TOUCH ME

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# **Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
#DO NOT TOUCH ME

# %% [markdown]
# # Great Job!
